# %%
from ultralytics import YOLO
from weighted_trainer import WeightedDetectionModel

model = YOLO("runs/detect/runs/Front/front_yolo26s_balance/weights/best.pt")
metrics = model.val(data="data/Front/data.yaml")

# 打印每个类别的 AP
for i, (name, ap) in enumerate(zip(metrics.names.values(), metrics.box.ap)):
    print(f"{name:15s}: AP@0.5 = {ap:.3f}")
# Out:
# Ultralytics 8.4.35  Python-3.12.12 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO26m summary (fused): 132 layers, 20,355,620 parameters, 0 gradients, 67.9 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 74.352.3 MB/s, size: 88.5 KB)
# val: Scanning I:\ProgramData\课堂专注度项目\SCB-YOLO\data\Front\val\labels.cache... 2660 images, 65 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2660/2660  0.0s
# val: I:\ProgramData\\SCB-YOLO\data\Front\val\images\12_000191.jpg: 1 duplicate labels removed
# val: I:\ProgramData\\SCB-YOLO\data\Front\val\images\12_000201.jpg: 1 duplicate labels removed
# val: I:\ProgramData\\SCB-YOLO\data\Front\val\images\12_000202.jpg: 1 duplicate labels removed
# val: I:\ProgramData\\SCB-YOLO\data\Front\val\images\12_000609.jpg: 3 duplicate labels removed
# val: I:\ProgramData\\SCB-YOLO\data\Front\val\images\12_000821.jpg: 1 duplicate labels removed
# ...
